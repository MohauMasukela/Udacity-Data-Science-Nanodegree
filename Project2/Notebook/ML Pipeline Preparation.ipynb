# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sqlalchemy import create_engine

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier

# %%
from sklearn.metrics import classification_report

# %%
#load data

def load_data():
    engine = create_engine('sqlite:///DisasterResponse.db')
    conn=engine.connect()
    df= pd.read_sql('select * from DisasterResponse', conn)
    return df

df=load_data()

# %%
import nltk
nltk.download('stopwords',quiet=True)
from nltk.corpus import stopwords

stop_words=stopwords.words('english')

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(df):
    #lower words
    df['message']=df['message'].apply(lambda x:' '.join([word.lower() for word in x.split()]))
    #remove special characters
    df['message']=df['message'].apply(lambda x:' '.join([(re.sub(r"[^a-zA-Z0-9]", " ", word))
                                                         for word in x.split()]))
    #remove stop words
    df['message']=df['message'].apply(lambda x:' '.join([word for word in x.split()
                                                         if word not in (stop_words)]))
    #tokenize
    #df["message"] = df["message"].apply(word_tokenize)
    
    # initiate lemmatizer
    lemmatizer = WordNetLemmatizer()
    X=df["message"]
    y=df.drop(columns =['id', 'message','original','genre'])

    return X,y

X,y=tokenize(df)

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
 pipeline = Pipeline([
        ('vect', CountVectorizer()),
        ('tfidf', TfidfTransformer()),
        ('clf',MultiOutputClassifier(RandomForestClassifier()))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
  
# train classifier
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
# predict on test data
y_pred = pipeline.predict(X_test)

# %%
# Printing the classification report for each label
def model_report(y_test, y_pred):
    i = 0
    for col in y_test:
        print('Feature {}: {}'.format(i+1, col))
        print(classification_report(y_test[col], y_pred[:, i]))
        i = i + 1
    accuracy = (y_pred == y_test.values).mean()
    print('The model accuracy is {:.3f}'.format(accuracy))

# %%
model_report(y_test, y_pred)
# Out:
# Feature 1: related
#               precision    recall  f1-score   support
#
#            0       0.72      0.42      0.53      1542
#            1       0.84      0.95      0.89      4965
#
#     accuracy                           0.82      6507
#    macro avg       0.78      0.68      0.71      6507
# weighted avg       0.81      0.82      0.80      6507
#
# Feature 2: request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      5305
#            1       0.84      0.50      0.63      1202
#
#     accuracy                           0.89      6507
#    macro avg       0.87      0.74      0.78      6507
# weighted avg       0.89      0.89      0.88      6507
#
# Feature 3: offer
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6470
#            1       0.00      0.00      0.00        37
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
# Feature 4: aid_related
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82      3761
#            1       0.77      0.69      0.73      2746
#
#     accuracy                           0.78      6507
#    macro avg       0.78      0.77      0.77      6507
# weighted avg       0.78      0.78      0.78      6507
#
# Feature 5: medical_help
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      5976
#            1       0.71      0.10      0.18       531
#
#     accuracy                           0.92      6507
#    macro avg       0.82      0.55      0.57      6507
# weighted avg       0.91      0.92      0.90      6507
#
# Feature 6: medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6161
#            1       0.76      0.08      0.15       346
#
#     accuracy                           0.95      6507
#    macro avg       0.85      0.54      0.56      6507
# weighted avg       0.94      0.95      0.93      6507
#
# Feature 7: search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6304
#            1       0.67      0.03      0.06       203
#
#     accuracy                           0.97      6507
#    macro avg       0.82      0.51      0.52      6507
# weighted avg       0.96      0.97      0.96      6507
#
# Feature 8: security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6400
#            1       0.00      0.00      0.00       107
#
#     accuracy                           0.98      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.97      0.98      0.98      6507
#
# Feature 9: military
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6287
#            1       0.77      0.08      0.14       220
#
#     accuracy                           0.97      6507
#    macro avg       0.87      0.54      0.56      6507
# weighted avg       0.96      0.97      0.96      6507
#
# Feature 10: child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6507
#
#     accuracy                           1.00      6507
#    macro avg       1.00      1.00      1.00      6507
# weighted avg       1.00      1.00      1.00      6507
#
# Feature 11: water
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6056
#            1       0.90      0.40      0.55       451
#
#     accuracy                           0.96      6507
#    macro avg       0.93      0.70      0.76      6507
# weighted avg       0.95      0.96      0.95      6507
#
# Feature 12: food
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5749
#            1       0.88      0.61      0.72       758
#
#     accuracy                           0.94      6507
#    macro avg       0.91      0.80      0.84      6507
# weighted avg       0.94      0.94      0.94      6507
#
# Feature 13: shelter
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      5930
#            1       0.83      0.38      0.52       577
#
#     accuracy                           0.94      6507
#    macro avg       0.89      0.68      0.74      6507
# weighted avg       0.93      0.94      0.93      6507
#
# Feature 14: clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6406
#            1       0.71      0.12      0.20       101
#
#     accuracy                           0.99      6507
#    macro avg       0.85      0.56      0.60      6507
# weighted avg       0.98      0.99      0.98      6507
#
# Feature 15: money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6364
#            1       0.50      0.01      0.01       143
#
#     accuracy                           0.98      6507
#    macro avg       0.74      0.50      0.50      6507
# weighted avg       0.97      0.98      0.97      6507
#
# Feature 16: missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6439
#            1       0.00      0.00      0.00        68
#
#     accuracy                           0.99      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.98      0.99      0.98      6507
#
# Feature 17: refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6293
#            1       0.50      0.02      0.04       214
#
#     accuracy                           0.97      6507
#    macro avg       0.73      0.51      0.51      6507
# weighted avg       0.95      0.97      0.95      6507
#
# Feature 18: death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6216
#            1       0.82      0.16      0.27       291
#
#     accuracy                           0.96      6507
#    macro avg       0.89      0.58      0.63      6507
# weighted avg       0.96      0.96      0.95      6507
#
# Feature 19: other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5611
#            1       0.56      0.03      0.06       896
#
#     accuracy                           0.86      6507
#    macro avg       0.71      0.51      0.49      6507
# weighted avg       0.82      0.86      0.81      6507
#
# Feature 20: infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6092
#            1       0.12      0.00      0.00       415
#
#     accuracy                           0.94      6507
#    macro avg       0.53      0.50      0.49      6507
# weighted avg       0.88      0.94      0.91      6507
#
# Feature 21: transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6230
#            1       0.62      0.08      0.15       277
#
#     accuracy                           0.96      6507
#    macro avg       0.79      0.54      0.56      6507
# weighted avg       0.95      0.96      0.94      6507
#
# Feature 22: buildings
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6188
#            1       0.84      0.16      0.27       319
#
#     accuracy                           0.96      6507
#    macro avg       0.90      0.58      0.63      6507
# weighted avg       0.95      0.96      0.94      6507
#
# Feature 23: electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6355
#            1       1.00      0.04      0.08       152
#
#     accuracy                           0.98      6507
#    macro avg       0.99      0.52      0.53      6507
# weighted avg       0.98      0.98      0.97      6507
#
# Feature 24: tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6464
#            1       0.00      0.00      0.00        43
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
# Feature 25: hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6445
#            1       0.00      0.00      0.00        62
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.98      0.99      0.99      6507
#
# Feature 26: shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6482
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      1.00      0.99      6507
#
# Feature 27: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6441
#            1       0.00      0.00      0.00        66
#
#     accuracy                           0.99      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.98      0.99      0.98      6507
#
# Feature 28: other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6217
#            1       0.00      0.00      0.00       290
#
#     accuracy                           0.96      6507
#    macro avg       0.48      0.50      0.49      6507
# weighted avg       0.91      0.96      0.93      6507
#
# Feature 29: weather_related
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      4742
#            1       0.84      0.69      0.76      1765
#
#     accuracy                           0.88      6507
#    macro avg       0.87      0.82      0.84      6507
# weighted avg       0.88      0.88      0.88      6507
#
# Feature 30: floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      5987
#            1       0.88      0.47      0.61       520
#
#     accuracy                           0.95      6507
#    macro avg       0.92      0.73      0.79      6507
# weighted avg       0.95      0.95      0.95      6507
#
# Feature 31: storm
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5937
#            1       0.76      0.53      0.62       570
#
#     accuracy                           0.94      6507
#    macro avg       0.86      0.76      0.80      6507
# weighted avg       0.94      0.94      0.94      6507
#
# Feature 32: fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6443
#            1       1.00      0.03      0.06        64
#
#     accuracy                           0.99      6507
#    macro avg       1.00      0.52      0.53      6507
# weighted avg       0.99      0.99      0.99      6507
#
# Feature 33: earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5919
#            1       0.88      0.77      0.82       588
#
#     accuracy                           0.97      6507
#    macro avg       0.93      0.88      0.90      6507
# weighted avg       0.97      0.97      0.97      6507
#
# Feature 34: cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6375
#            1       0.72      0.10      0.17       132
#
#     accuracy                           0.98      6507
#    macro avg       0.85      0.55      0.58      6507
# weighted avg       0.98      0.98      0.97      6507
#
# Feature 35: other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6172
#            1       0.38      0.02      0.04       335
#
#     accuracy                           0.95      6507
#    macro avg       0.67      0.51      0.51      6507
# weighted avg       0.92      0.95      0.93      6507
#
# Feature 36: direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      5198
#            1       0.81      0.39      0.53      1309
#
#     accuracy                           0.86      6507
#    macro avg       0.84      0.69      0.72      6507
# weighted avg       0.85      0.86      0.84      6507
#
# The model accuracy is 0.948

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect', CountVectorizer()),
#   ('tfidf', TfidfTransformer()),
#   ('clf', MultiOutputClassifier(estimator=RandomForestClassifier()))],
#  'verbose': False,
#  'vect': CountVectorizer(),
#  'tfidf': TfidfTransformer(),
#  'clf': MultiOutputClassifier(estimator=RandomForestClassifier()),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': None,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__bootstrap': True,
#  'clf__estimator__ccp_alpha': 0.0,
#  'clf__estimator__class_weight': None,
#  'clf__estimator__criterion': 'gini',
#  'clf__estimator__max_depth': None,
#  'clf__estimator__max_features': 'sqrt',
#  'clf__estimator__max_leaf_nodes': None,
#  'clf__estimator__max_samples': None,
#  'clf__estimator__min_impurity_decrease': 0.0,
#  'clf__estimator__min_samples_leaf': 1,
#  'clf__estimator__min_samples_split': 2,
#  'clf__estimator__min_weight_fraction_leaf': 0.0,
#  'clf__estimator__n_estimators': 100,
#  'clf__estimator__n_jobs': None,
#  'clf__estimator__oob_score': False,
#  'clf__estimator__random_state': None,
#  'clf__estimator__verbose': 0,
#  'clf__estimator__warm_start': False,
#  'clf__estimator': RandomForestClassifier(),
#  'clf__n_jobs': None}

# %%
    params = {
      
       'clf__estimator__n_estimators': [50, 100],

    }

# %%
# create grid search object 
cv = GridSearchCV(pipeline, param_grid=params,cv=3,n_jobs=-1,scoring="accuracy")

cv
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('vect', CountVectorizer()),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              n_jobs=-1, param_grid={'clf__estimator__n_estimators': [50, 100]},
#              scoring='accuracy')

# %%
cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('vect', CountVectorizer()),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              n_jobs=-1, param_grid={'clf__estimator__n_estimators': [50, 100]},
#              scoring='accuracy')

# %%
cv.best_params_
# Out:
# {'clf__estimator__n_estimators': 100}

# %% [markdown]
# ### 7. Test your model

# %%
y_pred = cv.predict(X_test)

# %%
model_report(y_test, y_pred)
# Out:
# Feature 1: related
#               precision    recall  f1-score   support
#
#            0       0.72      0.42      0.53      1542
#            1       0.84      0.95      0.89      4965
#
#     accuracy                           0.82      6507
#    macro avg       0.78      0.69      0.71      6507
# weighted avg       0.81      0.82      0.81      6507
#
# Feature 2: request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      5305
#            1       0.84      0.50      0.63      1202
#
#     accuracy                           0.89      6507
#    macro avg       0.87      0.74      0.78      6507
# weighted avg       0.89      0.89      0.88      6507
#
# Feature 3: offer
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6470
#            1       0.00      0.00      0.00        37
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
# Feature 4: aid_related
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81      3761
#            1       0.76      0.70      0.73      2746
#
#     accuracy                           0.78      6507
#    macro avg       0.77      0.77      0.77      6507
# weighted avg       0.78      0.78      0.78      6507
#
# Feature 5: medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      5976
#            1       0.66      0.07      0.12       531
#
#     accuracy                           0.92      6507
#    macro avg       0.79      0.53      0.54      6507
# weighted avg       0.90      0.92      0.89      6507
#
# Feature 6: medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6161
#            1       0.71      0.06      0.12       346
#
#     accuracy                           0.95      6507
#    macro avg       0.83      0.53      0.55      6507
# weighted avg       0.94      0.95      0.93      6507
#
# Feature 7: search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6304
#            1       0.80      0.02      0.04       203
#
#     accuracy                           0.97      6507
#    macro avg       0.88      0.51      0.51      6507
# weighted avg       0.96      0.97      0.95      6507
#
# Feature 8: security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6400
#            1       0.00      0.00      0.00       107
#
#     accuracy                           0.98      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.97      0.98      0.98      6507
#
# Feature 9: military
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6287
#            1       0.71      0.09      0.16       220
#
#     accuracy                           0.97      6507
#    macro avg       0.84      0.54      0.57      6507
# weighted avg       0.96      0.97      0.96      6507
#
# Feature 10: child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6507
#
#     accuracy                           1.00      6507
#    macro avg       1.00      1.00      1.00      6507
# weighted avg       1.00      1.00      1.00      6507
#
# Feature 11: water
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6056
#            1       0.90      0.36      0.52       451
#
#     accuracy                           0.95      6507
#    macro avg       0.93      0.68      0.75      6507
# weighted avg       0.95      0.95      0.94      6507
#
# Feature 12: food
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5749
#            1       0.86      0.62      0.72       758
#
#     accuracy                           0.94      6507
#    macro avg       0.90      0.80      0.84      6507
# weighted avg       0.94      0.94      0.94      6507
#
# Feature 13: shelter
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      5930
#            1       0.86      0.38      0.52       577
#
#     accuracy                           0.94      6507
#    macro avg       0.90      0.69      0.75      6507
# weighted avg       0.94      0.94      0.93      6507
#
# Feature 14: clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6406
#            1       0.71      0.10      0.17       101
#
#     accuracy                           0.99      6507
#    macro avg       0.85      0.55      0.58      6507
# weighted avg       0.98      0.99      0.98      6507
#
# Feature 15: money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6364
#            1       0.50      0.01      0.01       143
#
#     accuracy                           0.98      6507
#    macro avg       0.74      0.50      0.50      6507
# weighted avg       0.97      0.98      0.97      6507
#
# Feature 16: missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6439
#            1       0.00      0.00      0.00        68
#
#     accuracy                           0.99      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.98      0.99      0.98      6507
#
# Feature 17: refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6293
#            1       0.67      0.05      0.09       214
#
#     accuracy                           0.97      6507
#    macro avg       0.82      0.52      0.54      6507
# weighted avg       0.96      0.97      0.95      6507
#
# Feature 18: death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6216
#            1       0.80      0.14      0.24       291
#
#     accuracy                           0.96      6507
#    macro avg       0.88      0.57      0.61      6507
# weighted avg       0.95      0.96      0.95      6507
#
# Feature 19: other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5611
#            1       0.61      0.04      0.08       896
#
#     accuracy                           0.86      6507
#    macro avg       0.74      0.52      0.50      6507
# weighted avg       0.83      0.86      0.81      6507
#
# Feature 20: infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6092
#            1       0.33      0.00      0.00       415
#
#     accuracy                           0.94      6507
#    macro avg       0.63      0.50      0.49      6507
# weighted avg       0.90      0.94      0.91      6507
#
# Feature 21: transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6230
#            1       0.63      0.09      0.15       277
#
#     accuracy                           0.96      6507
#    macro avg       0.80      0.54      0.57      6507
# weighted avg       0.95      0.96      0.94      6507
#
# Feature 22: buildings
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6188
#            1       0.84      0.15      0.25       319
#
#     accuracy                           0.96      6507
#    macro avg       0.90      0.57      0.61      6507
# weighted avg       0.95      0.96      0.94      6507
#
# Feature 23: electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6355
#            1       0.88      0.05      0.09       152
#
#     accuracy                           0.98      6507
#    macro avg       0.93      0.52      0.54      6507
# weighted avg       0.98      0.98      0.97      6507
#
# Feature 24: tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6464
#            1       0.00      0.00      0.00        43
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
# Feature 25: hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6445
#            1       0.00      0.00      0.00        62
#
#     accuracy                           0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.98      0.99      0.99      6507
#
# Feature 26: shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6482
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      1.00      0.99      6507
#
# Feature 27: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6441
#            1       0.00      0.00      0.00        66
#
#     accuracy                           0.99      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.98      0.99      0.98      6507
#
# Feature 28: other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6217
#            1       0.00      0.00      0.00       290
#
#     accuracy                           0.96      6507
#    macro avg       0.48      0.50      0.49      6507
# weighted avg       0.91      0.96      0.93      6507
#
# Feature 29: weather_related
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      4742
#            1       0.85      0.71      0.77      1765
#
#     accuracy                           0.89      6507
#    macro avg       0.87      0.83      0.85      6507
# weighted avg       0.88      0.89      0.88      6507
#
# Feature 30: floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      5987
#            1       0.88      0.48      0.62       520
#
#     accuracy                           0.95      6507
#    macro avg       0.92      0.74      0.80      6507
# weighted avg       0.95      0.95      0.95      6507
#
# Feature 31: storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5937
#            1       0.78      0.51      0.61       570
#
#     accuracy                           0.94      6507
#    macro avg       0.87      0.75      0.79      6507
# weighted avg       0.94      0.94      0.94      6507
#
# Feature 32: fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6443
#            1       1.00      0.03      0.06        64
#
#     accuracy                           0.99      6507
#    macro avg       1.00      0.52      0.53      6507
# weighted avg       0.99      0.99      0.99      6507
#
# Feature 33: earthquake
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5919
#            1       0.89      0.76      0.82       588
#
#     accuracy                           0.97      6507
#    macro avg       0.93      0.87      0.90      6507
# weighted avg       0.97      0.97      0.97      6507
#
# Feature 34: cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6375
#            1       0.68      0.13      0.22       132
#
#     accuracy                           0.98      6507
#    macro avg       0.83      0.56      0.60      6507
# weighted avg       0.98      0.98      0.97      6507
#
# Feature 35: other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6172
#            1       0.46      0.03      0.06       335
#
#     accuracy                           0.95      6507
#    macro avg       0.70      0.52      0.52      6507
# weighted avg       0.92      0.95      0.93      6507
#
# Feature 36: direct_report
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      5198
#            1       0.81      0.41      0.54      1309
#
#     accuracy                           0.86      6507
#    macro avg       0.84      0.69      0.73      6507
# weighted avg       0.86      0.86      0.84      6507
#
# The model accuracy is 0.949

# %% [markdown]
# ### 8. Export your model as a pickle file

# %%
import pickle
filename = 'model.pkl'
pickle.dump(cv, open(filename, 'wb'))

# %% [markdown]
# ### 9. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
